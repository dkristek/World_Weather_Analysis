# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
coordinates = list(lat_lngs)

# %%
#list to hold cities
cities = []

#identify neareast city for each lat lon combo
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 743

# %%
# Import the requests library.
import requests
import sys
sys.path.insert(0, '..')
# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
#empty list for city data
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):
    
     # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(30)
        
     # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
     # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count +=1
    
        
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather['weather'][0]['description']
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | rikitea
# Processing Record 2 of Set 1 | douentza
# Processing Record 3 of Set 1 | port elizabeth
# Processing Record 4 of Set 1 | bredasdorp
# Processing Record 5 of Set 1 | kapaa
# Processing Record 6 of Set 1 | hilo
# Processing Record 7 of Set 1 | albany
# Processing Record 8 of Set 1 | carnarvon
# Processing Record 9 of Set 1 | rivers
# Processing Record 10 of Set 1 | nishihara
# Processing Record 11 of Set 1 | pevek
# Processing Record 12 of Set 1 | hobart
# Processing Record 13 of Set 1 | port hardy
# Processing Record 14 of Set 1 | victoria
# Processing Record 15 of Set 1 | taltal
# Processing Record 16 of Set 1 | okhotsk
# Processing Record 17 of Set 1 | luqiao
# Processing Record 18 of Set 1 | plettenberg bay
# Processing Record 19 of Set 1 | port lincoln
# Processing Record 20 of Set 1 | touros
# Processing Record 21 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 22 of Set 1 | latung
# Processing Record 23 of Set 1 | sao filipe
# Processing Record 24 of Set 1 | tasiilaq
# Processing Record 25 of Set 1 | busselton
# Processing Record 26 of Set 1 | changji
# Processing Record 27 of Set 1 | palmer
# Processing Record 28 of Set 1 | mahaicony
# City not found. Skipping...
# Processing Record 29 of Set 1 | marzuq
# Processing Record 30 of Set 1 | kamaishi
# Processing Record 31 of Set 1 | eureka
# Processing Record 32 of Set 1 | north bend
# Processing Record 33 of Set 1 | ushuaia
# Processing Record 34 of Set 1 | mount gambier
# Processing Record 35 of Set 1 | punta arenas
# Processing Record 36 of Set 1 | dingle
# Processing Record 37 of Set 1 | puerto baquerizo moreno
# Processing Record 38 of Set 1 | atuona
# Processing Record 39 of Set 1 | euclides da cunha
# Processing Record 40 of Set 1 | yellowknife
# Processing Record 41 of Set 1 | byron bay
# Processing Record 42 of Set 1 | san rafael
# Processing Record 43 of Set 1 | tuktoyaktuk
# Processing Record 44 of Set 1 | buala
# Processing Record 45 of Set 1 | ksenyevka
# City not found. Skipping...
# Processing Record 46 of Set 1 | middelburg
# Processing Record 47 of Set 1 | avera
# Processing Record 48 of Set 1 | walvis bay
# Processing Record 49 of Set 1 | sulangan
# Processing Record 50 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 1 of Set 2 | acapulco
# Processing Record 2 of Set 2 | beruwala
# Processing Record 3 of Set 2 | kazalinsk
# City not found. Skipping...
# Processing Record 4 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 5 of Set 2 | bathsheba
# Processing Record 6 of Set 2 | ca mau
# Processing Record 7 of Set 2 | dikson
# Processing Record 8 of Set 2 | mar del plata
# Processing Record 9 of Set 2 | karakendzha
# City not found. Skipping...
# Processing Record 10 of Set 2 | ketchikan
# Processing Record 11 of Set 2 | hasaki
# Processing Record 12 of Set 2 | port alfred
# Processing Record 13 of Set 2 | zhigansk
# Processing Record 14 of Set 2 | labuhan
# Processing Record 15 of Set 2 | lorengau
# Processing Record 16 of Set 2 | krasnoselkup
# Processing Record 17 of Set 2 | husavik
# Processing Record 18 of Set 2 | thompson
# Processing Record 19 of Set 2 | banjar
# Processing Record 20 of Set 2 | omboue
# Processing Record 21 of Set 2 | muros
# Processing Record 22 of Set 2 | bubaque
# Processing Record 23 of Set 2 | hithadhoo
# Processing Record 24 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 25 of Set 2 | bahir dar
# Processing Record 26 of Set 2 | santa rosalia
# Processing Record 27 of Set 2 | nikolskoye
# Processing Record 28 of Set 2 | terre haute
# Processing Record 29 of Set 2 | lakes entrance
# Processing Record 30 of Set 2 | kazachinskoye
# Processing Record 31 of Set 2 | constantine
# Processing Record 32 of Set 2 | ilulissat
# Processing Record 33 of Set 2 | bengkulu
# Processing Record 34 of Set 2 | palm springs
# Processing Record 35 of Set 2 | puerto ayora
# Processing Record 36 of Set 2 | nijar
# Processing Record 37 of Set 2 | tupik
# Processing Record 38 of Set 2 | bambous virieux
# Processing Record 39 of Set 2 | mount vernon
# Processing Record 40 of Set 2 | chokurdakh
# Processing Record 41 of Set 2 | vao
# Processing Record 42 of Set 2 | saldanha
# Processing Record 43 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 44 of Set 2 | bethel
# Processing Record 45 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 46 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 47 of Set 2 | neman
# Processing Record 48 of Set 2 | vila velha
# Processing Record 49 of Set 2 | tuatapere
# Processing Record 50 of Set 2 | tamandare
# Processing Record 1 of Set 3 | lebu
# Processing Record 2 of Set 3 | ravar
# Processing Record 3 of Set 3 | georgetown
# Processing Record 4 of Set 3 | sitka
# Processing Record 5 of Set 3 | pahrump
# Processing Record 6 of Set 3 | oyama
# Processing Record 7 of Set 3 | colares
# Processing Record 8 of Set 3 | xam nua
# Processing Record 9 of Set 3 | esperance
# Processing Record 10 of Set 3 | saskylakh
# Processing Record 11 of Set 3 | karamay
# City not found. Skipping...
# Processing Record 12 of Set 3 | takoradi
# Processing Record 13 of Set 3 | bluff
# Processing Record 14 of Set 3 | upernavik
# Processing Record 15 of Set 3 | butaritari
# Processing Record 16 of Set 3 | keti bandar
# Processing Record 17 of Set 3 | cape town
# Processing Record 18 of Set 3 | narrabri
# Processing Record 19 of Set 3 | nampula
# Processing Record 20 of Set 3 | chuy
# Processing Record 21 of Set 3 | talnakh
# Processing Record 22 of Set 3 | saint-philippe
# Processing Record 23 of Set 3 | ijaki
# City not found. Skipping...
# Processing Record 24 of Set 3 | tommot
# Processing Record 25 of Set 3 | grand gaube
# Processing Record 26 of Set 3 | tulun
# Processing Record 27 of Set 3 | lumberton
# Processing Record 28 of Set 3 | gwadar
# Processing Record 29 of Set 3 | kyren
# Processing Record 30 of Set 3 | katsuura
# Processing Record 31 of Set 3 | jamestown
# Processing Record 32 of Set 3 | longyearbyen
# Processing Record 33 of Set 3 | ulaangom
# Processing Record 34 of Set 3 | dhidhdhoo
# Processing Record 35 of Set 3 | huarmey
# Processing Record 36 of Set 3 | santa cruz
# Processing Record 37 of Set 3 | roma
# Processing Record 38 of Set 3 | kununurra
# Processing Record 39 of Set 3 | kisangani
# Processing Record 40 of Set 3 | biltine
# Processing Record 41 of Set 3 | amahai
# Processing Record 42 of Set 3 | cockburn town
# Processing Record 43 of Set 3 | iqaluit
# Processing Record 44 of Set 3 | cherskiy
# Processing Record 45 of Set 3 | axim
# Processing Record 46 of Set 3 | kushiro
# Processing Record 47 of Set 3 | tiarei
# Processing Record 48 of Set 3 | mataura
# Processing Record 49 of Set 3 | tshikapa
# Processing Record 50 of Set 3 | taoudenni
# Processing Record 1 of Set 4 | ponta do sol
# Processing Record 2 of Set 4 | oriximina
# Processing Record 3 of Set 4 | port macquarie
# Processing Record 4 of Set 4 | hualmay
# Processing Record 5 of Set 4 | new norfolk
# Processing Record 6 of Set 4 | coquimbo
# Processing Record 7 of Set 4 | plyussa
# Processing Record 8 of Set 4 | viligili
# City not found. Skipping...
# Processing Record 9 of Set 4 | westport
# Processing Record 10 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 11 of Set 4 | faanui
# Processing Record 12 of Set 4 | arraial do cabo
# Processing Record 13 of Set 4 | halol
# Processing Record 14 of Set 4 | sinnamary
# Processing Record 15 of Set 4 | kodiak
# Processing Record 16 of Set 4 | sernur
# Processing Record 17 of Set 4 | hamilton
# Processing Record 18 of Set 4 | beipiao
# Processing Record 19 of Set 4 | khatanga
# Processing Record 20 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 21 of Set 4 | hvammstangi
# City not found. Skipping...
# Processing Record 22 of Set 4 | kanye
# Processing Record 23 of Set 4 | fortuna
# Processing Record 24 of Set 4 | praia da vitoria
# Processing Record 25 of Set 4 | de aar
# Processing Record 26 of Set 4 | udachnyy
# Processing Record 27 of Set 4 | castro
# Processing Record 28 of Set 4 | vanimo
# Processing Record 29 of Set 4 | sola
# Processing Record 30 of Set 4 | aktash
# Processing Record 31 of Set 4 | sataua
# City not found. Skipping...
# Processing Record 32 of Set 4 | ancud
# Processing Record 33 of Set 4 | davila
# Processing Record 34 of Set 4 | middleton
# Processing Record 35 of Set 4 | ixtapa
# Processing Record 36 of Set 4 | bud
# Processing Record 37 of Set 4 | ciudad bolivar
# Processing Record 38 of Set 4 | east london
# Processing Record 39 of Set 4 | barrow
# Processing Record 40 of Set 4 | hermanus
# Processing Record 41 of Set 4 | yinchuan
# Processing Record 42 of Set 4 | pangnirtung
# Processing Record 43 of Set 4 | provideniya
# Processing Record 44 of Set 4 | ryotsu
# Processing Record 45 of Set 4 | alice springs
# Processing Record 46 of Set 4 | kieta
# Processing Record 47 of Set 4 | geraldton
# Processing Record 48 of Set 4 | batagay
# Processing Record 49 of Set 4 | qaanaaq
# Processing Record 50 of Set 4 | los llanos de aridane
# Processing Record 1 of Set 5 | caraballeda
# Processing Record 2 of Set 5 | ulladulla
# Processing Record 3 of Set 5 | cabo san lucas
# Processing Record 4 of Set 5 | shimoda
# Processing Record 5 of Set 5 | buin
# Processing Record 6 of Set 5 | gold coast
# Processing Record 7 of Set 5 | deputatskiy
# Processing Record 8 of Set 5 | avarua
# Processing Record 9 of Set 5 | leningradskiy
# Processing Record 10 of Set 5 | campoverde
# Processing Record 11 of Set 5 | vaini
# Processing Record 12 of Set 5 | ust-kuyga
# Processing Record 13 of Set 5 | yagodnoye
# Processing Record 14 of Set 5 | ambikapur
# Processing Record 15 of Set 5 | komsomolets
# Processing Record 16 of Set 5 | muravlenko
# Processing Record 17 of Set 5 | buenos aires
# Processing Record 18 of Set 5 | nguiu
# City not found. Skipping...
# Processing Record 19 of Set 5 | tarko-sale
# Processing Record 20 of Set 5 | gollere
# City not found. Skipping...
# Processing Record 21 of Set 5 | khudumelapye
# Processing Record 22 of Set 5 | airai
# Processing Record 23 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 24 of Set 5 | lavrentiya
# Processing Record 25 of Set 5 | dzhusaly
# City not found. Skipping...
# Processing Record 26 of Set 5 | qandahar
# City not found. Skipping...
# Processing Record 27 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 28 of Set 5 | ananas
# Processing Record 29 of Set 5 | mehamn
# Processing Record 30 of Set 5 | tessalit
# Processing Record 31 of Set 5 | kuzino
# Processing Record 32 of Set 5 | chagda
# City not found. Skipping...
# Processing Record 33 of Set 5 | yaan
# Processing Record 34 of Set 5 | moranbah
# Processing Record 35 of Set 5 | bilma
# Processing Record 36 of Set 5 | saleilua
# City not found. Skipping...
# Processing Record 37 of Set 5 | lompoc
# Processing Record 38 of Set 5 | sur
# Processing Record 39 of Set 5 | matara
# Processing Record 40 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 41 of Set 5 | sattahip
# Processing Record 42 of Set 5 | ribeira grande
# Processing Record 43 of Set 5 | marabba
# Processing Record 44 of Set 5 | huilong
# Processing Record 45 of Set 5 | tautira
# Processing Record 46 of Set 5 | coahuayana
# Processing Record 47 of Set 5 | mormugao
# Processing Record 48 of Set 5 | rongcheng
# Processing Record 49 of Set 5 | nauta
# Processing Record 50 of Set 5 | beringovskiy
# Processing Record 1 of Set 6 | buta
# Processing Record 2 of Set 6 | parana
# Processing Record 3 of Set 6 | chumikan
# Processing Record 4 of Set 6 | antofagasta
# Processing Record 5 of Set 6 | san vicente
# Processing Record 6 of Set 6 | roccastrada
# Processing Record 7 of Set 6 | colon
# Processing Record 8 of Set 6 | verkhnyaya inta
# Processing Record 9 of Set 6 | port-gentil
# Processing Record 10 of Set 6 | bezenchuk
# Processing Record 11 of Set 6 | esso
# Processing Record 12 of Set 6 | hobyo
# Processing Record 13 of Set 6 | praia
# Processing Record 14 of Set 6 | luderitz
# Processing Record 15 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 16 of Set 6 | toftir
# City not found. Skipping...
# Processing Record 17 of Set 6 | kruisfontein
# Processing Record 18 of Set 6 | samfya
# Processing Record 19 of Set 6 | san quintin
# Processing Record 20 of Set 6 | nome
# Processing Record 21 of Set 6 | sao joao da barra
# Processing Record 22 of Set 6 | kaitangata
# Processing Record 23 of Set 6 | quesnel
# Processing Record 24 of Set 6 | ust-maya
# Processing Record 25 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 26 of Set 6 | tiksi
# Processing Record 27 of Set 6 | indiaroba
# Processing Record 28 of Set 6 | santa cruz cabralia
# Processing Record 29 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 30 of Set 6 | dudinka
# Processing Record 31 of Set 6 | charlestown
# Processing Record 32 of Set 6 | narsaq
# Processing Record 33 of Set 6 | dayong
# Processing Record 34 of Set 6 | opuwo
# Processing Record 35 of Set 6 | port hedland
# Processing Record 36 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 37 of Set 6 | bowen
# Processing Record 38 of Set 6 | bonthe
# Processing Record 39 of Set 6 | kavieng
# Processing Record 40 of Set 6 | yangambi
# Processing Record 41 of Set 6 | rio gallegos
# Processing Record 42 of Set 6 | saint anthony
# Processing Record 43 of Set 6 | xiaoshan
# Processing Record 44 of Set 6 | dekar
# Processing Record 45 of Set 6 | kayes
# Processing Record 46 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 47 of Set 6 | kapit
# Processing Record 48 of Set 6 | bagrami
# Processing Record 49 of Set 6 | karratha
# Processing Record 50 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 1 of Set 7 | sovetskiy
# Processing Record 2 of Set 7 | arlit
# Processing Record 3 of Set 7 | saint george
# Processing Record 4 of Set 7 | adrar
# Processing Record 5 of Set 7 | slave lake
# Processing Record 6 of Set 7 | severo-kurilsk
# Processing Record 7 of Set 7 | kahului
# Processing Record 8 of Set 7 | sampit
# Processing Record 9 of Set 7 | dabat
# Processing Record 10 of Set 7 | corralillo
# Processing Record 11 of Set 7 | shenjiamen
# Processing Record 12 of Set 7 | tabory
# Processing Record 13 of Set 7 | ambon
# Processing Record 14 of Set 7 | ngukurr
# City not found. Skipping...
# Processing Record 15 of Set 7 | homer
# Processing Record 16 of Set 7 | bandarbeyla
# Processing Record 17 of Set 7 | asyut
# Processing Record 18 of Set 7 | ambovombe
# Processing Record 19 of Set 7 | gua musang
# Processing Record 20 of Set 7 | barra do garcas
# Processing Record 21 of Set 7 | sabang
# Processing Record 22 of Set 7 | sao paulo de olivenca
# Processing Record 23 of Set 7 | rawlins
# Processing Record 24 of Set 7 | puerto madryn
# Processing Record 25 of Set 7 | evensk
# Processing Record 26 of Set 7 | sioux lookout
# Processing Record 27 of Set 7 | dondo
# Processing Record 28 of Set 7 | batamshinskiy
# Processing Record 29 of Set 7 | tateyama
# Processing Record 30 of Set 7 | lalian
# Processing Record 31 of Set 7 | nikki
# Processing Record 32 of Set 7 | coripata
# Processing Record 33 of Set 7 | paita
# Processing Record 34 of Set 7 | norman wells
# Processing Record 35 of Set 7 | tiznit
# Processing Record 36 of Set 7 | binzhou
# Processing Record 37 of Set 7 | lodja
# Processing Record 38 of Set 7 | port shepstone
# City not found. Skipping...
# Processing Record 39 of Set 7 | torbay
# City not found. Skipping...
# Processing Record 40 of Set 7 | cabedelo
# City not found. Skipping...
# Processing Record 41 of Set 7 | bogoslovka
# City not found. Skipping...
# Processing Record 42 of Set 7 | trincomalee
# City not found. Skipping...
# Processing Record 43 of Set 7 | constitucion
# City not found. Skipping...
# Processing Record 44 of Set 7 | rocha
# City not found. Skipping...
# Processing Record 45 of Set 7 | havoysund
# City not found. Skipping...
# Processing Record 46 of Set 7 | vestmanna
# City not found. Skipping...
# Processing Record 47 of Set 7 | ostrovnoy
# City not found. Skipping...
# Processing Record 48 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 49 of Set 7 | whakatane
# City not found. Skipping...
# Processing Record 50 of Set 7 | koslan
# Processing Record 1 of Set 8 | laguna
# Processing Record 2 of Set 8 | bilibino
# Processing Record 3 of Set 8 | valdivia
# Processing Record 4 of Set 8 | broome
# Processing Record 5 of Set 8 | guerrero negro
# Processing Record 6 of Set 8 | xining
# Processing Record 7 of Set 8 | codrington
# Processing Record 8 of Set 8 | yenagoa
# Processing Record 9 of Set 8 | souillac
# Processing Record 10 of Set 8 | nouadhibou
# Processing Record 11 of Set 8 | luwuk
# Processing Record 12 of Set 8 | sisophon
# Processing Record 13 of Set 8 | pontianak
# Processing Record 14 of Set 8 | erenhot
# Processing Record 15 of Set 8 | qala
# Processing Record 16 of Set 8 | bosobolo
# Processing Record 17 of Set 8 | sayyan
# Processing Record 18 of Set 8 | pundaguitan
# Processing Record 19 of Set 8 | kharp
# Processing Record 20 of Set 8 | clyde river
# Processing Record 21 of Set 8 | valentin gomez farias
# Processing Record 22 of Set 8 | koumac
# Processing Record 23 of Set 8 | havre-saint-pierre
# Processing Record 24 of Set 8 | itacarambi
# Processing Record 25 of Set 8 | casino
# Processing Record 26 of Set 8 | cuiluan
# Processing Record 27 of Set 8 | oksfjord
# Processing Record 28 of Set 8 | anadyr
# Processing Record 29 of Set 8 | honningsvag
# Processing Record 30 of Set 8 | namibe
# Processing Record 31 of Set 8 | domna
# Processing Record 32 of Set 8 | chimbote
# Processing Record 33 of Set 8 | rumphi
# Processing Record 34 of Set 8 | bokoro
# Processing Record 35 of Set 8 | saint-anselme
# Processing Record 36 of Set 8 | vastervik
# City not found. Skipping...
# Processing Record 37 of Set 8 | kendari
# Processing Record 38 of Set 8 | longhua
# Processing Record 39 of Set 8 | japura
# Processing Record 40 of Set 8 | skalistyy
# City not found. Skipping...
# Processing Record 41 of Set 8 | pemangkat
# Processing Record 42 of Set 8 | kuching
# Processing Record 43 of Set 8 | tongchuan
# Processing Record 44 of Set 8 | zeya
# Processing Record 45 of Set 8 | tocopilla
# Processing Record 46 of Set 8 | traian
# Processing Record 47 of Set 8 | jawar
# Processing Record 48 of Set 8 | warrington
# Processing Record 49 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 50 of Set 8 | hambantota
# Processing Record 1 of Set 9 | mahebourg
# Processing Record 2 of Set 9 | yuanping
# Processing Record 3 of Set 9 | green valley
# Processing Record 4 of Set 9 | salinas
# Processing Record 5 of Set 9 | asau
# Processing Record 6 of Set 9 | vienna
# Processing Record 7 of Set 9 | vallenar
# Processing Record 8 of Set 9 | meulaboh
# Processing Record 9 of Set 9 | kalevala
# Processing Record 10 of Set 9 | bahia blanca
# Processing Record 11 of Set 9 | chicama
# Processing Record 12 of Set 9 | timiryazevskoye
# Processing Record 13 of Set 9 | nalut
# Processing Record 14 of Set 9 | muli
# Processing Record 15 of Set 9 | pakala
# Processing Record 16 of Set 9 | xiongzhou
# Processing Record 17 of Set 9 | henties bay
# Processing Record 18 of Set 9 | tecoanapa
# Processing Record 19 of Set 9 | zyryanka
# Processing Record 20 of Set 9 | baykit
# Processing Record 21 of Set 9 | garden city
# Processing Record 22 of Set 9 | cidreira
# Processing Record 23 of Set 9 | tunggol
# Processing Record 24 of Set 9 | san cristobal
# Processing Record 25 of Set 9 | ellensburg
# Processing Record 26 of Set 9 | totskoye
# Processing Record 27 of Set 9 | talara
# Processing Record 28 of Set 9 | gazanjyk
# Processing Record 29 of Set 9 | tabou
# Processing Record 30 of Set 9 | george
# Processing Record 31 of Set 9 | waw
# Processing Record 32 of Set 9 | turkistan
# Processing Record 33 of Set 9 | moscow
# Processing Record 34 of Set 9 | florida
# Processing Record 35 of Set 9 | yar-sale
# Processing Record 36 of Set 9 | klaksvik
# Processing Record 37 of Set 9 | gejiu
# Processing Record 38 of Set 9 | csokmo
# Processing Record 39 of Set 9 | tadine
# Processing Record 40 of Set 9 | komsomolskiy
# Processing Record 41 of Set 9 | mahon
# Processing Record 42 of Set 9 | half moon bay
# Processing Record 43 of Set 9 | te anau
# Processing Record 44 of Set 9 | barcelos
# Processing Record 45 of Set 9 | kloulklubed
# Processing Record 46 of Set 9 | mezen
# Processing Record 47 of Set 9 | berezovyy
# Processing Record 48 of Set 9 | pacifica
# Processing Record 49 of Set 9 | savannah bight
# Processing Record 50 of Set 9 | jardim
# Processing Record 1 of Set 10 | mrirt
# City not found. Skipping...
# Processing Record 2 of Set 10 | jiuquan
# Processing Record 3 of Set 10 | xichang
# Processing Record 4 of Set 10 | nhulunbuy
# Processing Record 5 of Set 10 | gao
# Processing Record 6 of Set 10 | margate
# Processing Record 7 of Set 10 | nuuk
# Processing Record 8 of Set 10 | sao miguel do araguaia
# Processing Record 9 of Set 10 | miles city
# Processing Record 10 of Set 10 | katherine
# Processing Record 11 of Set 10 | lensk
# Processing Record 12 of Set 10 | port blair
# Processing Record 13 of Set 10 | pisco
# Processing Record 14 of Set 10 | salihorsk
# Processing Record 15 of Set 10 | havre
# Processing Record 16 of Set 10 | pangai
# Processing Record 17 of Set 10 | marienburg
# Processing Record 18 of Set 10 | parry sound
# Processing Record 19 of Set 10 | vardo
# Processing Record 20 of Set 10 | sundsvall
# Processing Record 21 of Set 10 | caravelas
# Processing Record 22 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 23 of Set 10 | ballina
# Processing Record 24 of Set 10 | bhinga
# Processing Record 25 of Set 10 | naron
# Processing Record 26 of Set 10 | flinders
# Processing Record 27 of Set 10 | myitkyina
# Processing Record 28 of Set 10 | ugoofaaru
# Processing Record 29 of Set 10 | sulphur springs
# Processing Record 30 of Set 10 | mineiros
# Processing Record 31 of Set 10 | kapuskasing
# Processing Record 32 of Set 10 | porto uniao
# Processing Record 33 of Set 10 | namatanai
# Processing Record 34 of Set 10 | soderhamn
# Processing Record 35 of Set 10 | tabulbah
# City not found. Skipping...
# Processing Record 36 of Set 10 | borovoy
# Processing Record 37 of Set 10 | dunedin
# Processing Record 38 of Set 10 | umea
# Processing Record 39 of Set 10 | kualakapuas
# Processing Record 40 of Set 10 | akhmim
# Processing Record 41 of Set 10 | borogontsy
# Processing Record 42 of Set 10 | isangel
# Processing Record 43 of Set 10 | arman
# Processing Record 44 of Set 10 | hokitika
# Processing Record 45 of Set 10 | wukari
# Processing Record 46 of Set 10 | zarand
# Processing Record 47 of Set 10 | yairipok
# Processing Record 48 of Set 10 | dedza
# Processing Record 49 of Set 10 | sijunjung
# Processing Record 50 of Set 10 | karlshamn
# Processing Record 1 of Set 11 | nanortalik
# Processing Record 2 of Set 11 | lincoln
# Processing Record 3 of Set 11 | cuamba
# Processing Record 4 of Set 11 | riyadh
# Processing Record 5 of Set 11 | beloha
# Processing Record 6 of Set 11 | prince rupert
# Processing Record 7 of Set 11 | hasanabad
# Processing Record 8 of Set 11 | richards bay
# Processing Record 9 of Set 11 | yulara
# Processing Record 10 of Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 11 of Set 11 | tambo
# Processing Record 12 of Set 11 | birao
# Processing Record 13 of Set 11 | maku
# Processing Record 14 of Set 11 | palmas
# Processing Record 15 of Set 11 | dutlwe
# Processing Record 16 of Set 11 | toguchin
# Processing Record 17 of Set 11 | alyangula
# Processing Record 18 of Set 11 | kirakira
# Processing Record 19 of Set 11 | gangotri
# City not found. Skipping...
# Processing Record 20 of Set 11 | brainerd
# Processing Record 21 of Set 11 | kadykchan
# City not found. Skipping...
# Processing Record 22 of Set 11 | rabo de peixe
# Processing Record 23 of Set 11 | chifeng
# Processing Record 24 of Set 11 | ternate
# Processing Record 25 of Set 11 | gondanglegi
# Processing Record 26 of Set 11 | port keats
# Processing Record 27 of Set 11 | san juan del sur
# Processing Record 28 of Set 11 | jennings
# Processing Record 29 of Set 11 | dombarovskiy
# Processing Record 30 of Set 11 | maniitsoq
# Processing Record 31 of Set 11 | saint-francois
# Processing Record 32 of Set 11 | dezhou
# Processing Record 33 of Set 11 | utinga
# Processing Record 34 of Set 11 | mlonggo
# Processing Record 35 of Set 11 | aldan
# Processing Record 36 of Set 11 | jabiru
# City not found. Skipping...
# Processing Record 37 of Set 11 | gikongoro
# Processing Record 38 of Set 11 | ha tinh
# Processing Record 39 of Set 11 | oistins
# Processing Record 40 of Set 11 | agadez
# Processing Record 41 of Set 11 | cap malheureux
# Processing Record 42 of Set 11 | mehran
# Processing Record 43 of Set 11 | libreville
# Processing Record 44 of Set 11 | oranjemund
# Processing Record 45 of Set 11 | chase
# Processing Record 46 of Set 11 | ahuimanu
# Processing Record 47 of Set 11 | tura
# Processing Record 48 of Set 11 | saint-georges
# Processing Record 49 of Set 11 | mount isa
# Processing Record 50 of Set 11 | itarema
# Processing Record 1 of Set 12 | indianola
# Processing Record 2 of Set 12 | mishkino
# Processing Record 3 of Set 12 | palestine
# Processing Record 4 of Set 12 | moree
# Processing Record 5 of Set 12 | padang
# Processing Record 6 of Set 12 | rawannawi
# City not found. Skipping...
# Processing Record 7 of Set 12 | nizhniy kuranakh
# Processing Record 8 of Set 12 | noumea
# Processing Record 9 of Set 12 | iacu
# Processing Record 10 of Set 12 | goma
# Processing Record 11 of Set 12 | satitoa
# City not found. Skipping...
# Processing Record 12 of Set 12 | deh rawud
# City not found. Skipping...
# Processing Record 13 of Set 12 | illapel
# Processing Record 14 of Set 12 | sambava
# Processing Record 15 of Set 12 | saint helens
# Processing Record 16 of Set 12 | kassala
# Processing Record 17 of Set 12 | qingan
# City not found. Skipping...
# Processing Record 18 of Set 12 | madawaska
# Processing Record 19 of Set 12 | taseyevo
# Processing Record 20 of Set 12 | kabanjahe
# Processing Record 21 of Set 12 | monrovia
# Processing Record 22 of Set 12 | burns lake
# Processing Record 23 of Set 12 | payo
# Processing Record 24 of Set 12 | korla
# Processing Record 25 of Set 12 | payyannur
# Processing Record 26 of Set 12 | rafaela
# Processing Record 27 of Set 12 | missoula
# Processing Record 28 of Set 12 | cajabamba
# Processing Record 29 of Set 12 | baruun-urt
# Processing Record 30 of Set 12 | morehead
# Processing Record 31 of Set 12 | mpika
# Processing Record 32 of Set 12 | careiro da varzea
# Processing Record 33 of Set 12 | sabaudia
# Processing Record 34 of Set 12 | lexington
# Processing Record 35 of Set 12 | madang
# Processing Record 36 of Set 12 | puerto escondido
# Processing Record 37 of Set 12 | pimenta bueno
# Processing Record 38 of Set 12 | norsup
# Processing Record 39 of Set 12 | chukhloma
# Processing Record 40 of Set 12 | aklavik
# Processing Record 41 of Set 12 | butajira
# Processing Record 42 of Set 12 | juneau
# Processing Record 43 of Set 12 | saurimo
# Processing Record 44 of Set 12 | agadir
# Processing Record 45 of Set 12 | astaneh-ye ashrafiyeh
# Processing Record 46 of Set 12 | ahipara
# Processing Record 47 of Set 12 | chhatapur
# Processing Record 48 of Set 12 | varkkallai
# Processing Record 49 of Set 12 | ilinskiy
# Processing Record 50 of Set 12 | potosi
# Processing Record 1 of Set 13 | coro
# Processing Record 2 of Set 13 | umm jarr
# City not found. Skipping...
# Processing Record 3 of Set 13 | alofi
# Processing Record 4 of Set 13 | seoul
# Processing Record 5 of Set 13 | gurskoye
# City not found. Skipping...
# Processing Record 6 of Set 13 | toora-khem
# Processing Record 7 of Set 13 | russell
# Processing Record 8 of Set 13 | basi
# Processing Record 9 of Set 13 | palabuhanratu
# City not found. Skipping...
# Processing Record 10 of Set 13 | ljungby
# Processing Record 11 of Set 13 | andenes
# Processing Record 12 of Set 13 | thanh hoa
# Processing Record 13 of Set 13 | awjilah
# Processing Record 14 of Set 13 | ayr
# Processing Record 15 of Set 13 | kabo
# Processing Record 16 of Set 13 | pinyug
# Processing Record 17 of Set 13 | sungairaya
# Processing Record 18 of Set 13 | agboville
# Processing Record 19 of Set 13 | abu zabad
# Processing Record 20 of Set 13 | santa isabel do rio negro
# Processing Record 21 of Set 13 | naze
# Processing Record 22 of Set 13 | port moresby
# Processing Record 23 of Set 13 | scottsburgh
# City not found. Skipping...
# Processing Record 24 of Set 13 | srednekolymsk
# Processing Record 25 of Set 13 | strezhevoy
# Processing Record 26 of Set 13 | buraydah
# Processing Record 27 of Set 13 | honiara
# Processing Record 28 of Set 13 | kulhudhuffushi
# Processing Record 29 of Set 13 | paamiut
# Processing Record 30 of Set 13 | talikota
# Processing Record 31 of Set 13 | kattivakkam
# Processing Record 32 of Set 13 | moron
# Processing Record 33 of Set 13 | cabra
# Processing Record 34 of Set 13 | suntar
# Processing Record 35 of Set 13 | lagoa
# Processing Record 36 of Set 13 | predivinsk
# Processing Record 37 of Set 13 | duncan
# Processing Record 38 of Set 13 | safaga
# Processing Record 39 of Set 13 | nigran
# Processing Record 40 of Set 13 | jiazi
# Processing Record 41 of Set 13 | atagay
# Processing Record 42 of Set 13 | jalu
# Processing Record 43 of Set 13 | soligalich
# Processing Record 44 of Set 13 | kyaiklat
# Processing Record 45 of Set 13 | yialos
# City not found. Skipping...
# Processing Record 46 of Set 13 | neuquen
# Processing Record 47 of Set 13 | kharod
# Processing Record 48 of Set 13 | mbalmayo
# Processing Record 49 of Set 13 | san patricio
# Processing Record 50 of Set 13 | vila franca do campo
# Processing Record 1 of Set 14 | panlaitan
# Processing Record 2 of Set 14 | muroto
# Processing Record 3 of Set 14 | hay river
# Processing Record 4 of Set 14 | vilyuysk
# Processing Record 5 of Set 14 | cayenne
# Processing Record 6 of Set 14 | kuche
# City not found. Skipping...
# Processing Record 7 of Set 14 | veraval
# Processing Record 8 of Set 14 | aykhal
# Processing Record 9 of Set 14 | bafra
# Processing Record 10 of Set 14 | guapo
# Processing Record 11 of Set 14 | dwarka
# Processing Record 12 of Set 14 | ankara
# Processing Record 13 of Set 14 | nantucket
# Processing Record 14 of Set 14 | magadan
# Processing Record 15 of Set 14 | arboletes
# Processing Record 16 of Set 14 | basoko
# Processing Record 17 of Set 14 | olafsvik
# Processing Record 18 of Set 14 | taldan
# Processing Record 19 of Set 14 | hailar
# Processing Record 20 of Set 14 | we
# City not found. Skipping...
# Processing Record 21 of Set 14 | ahmadabad
# Processing Record 22 of Set 14 | mochalishche
# Processing Record 23 of Set 14 | poum
# Processing Record 24 of Set 14 | egvekinot
# Processing Record 25 of Set 14 | villa carlos paz
# Processing Record 26 of Set 14 | minna
# Processing Record 27 of Set 14 | guna
# Processing Record 28 of Set 14 | preobrazhenskaya
# City not found. Skipping...
# Processing Record 29 of Set 14 | asosa
# Processing Record 30 of Set 14 | sorland
# Processing Record 31 of Set 14 | hovd
# Processing Record 32 of Set 14 | sretensk
# Processing Record 33 of Set 14 | czarnkow
# Processing Record 34 of Set 14 | orlik
# Processing Record 35 of Set 14 | jacksonville
# Processing Record 36 of Set 14 | coihaique
# Processing Record 37 of Set 14 | sangar
# Processing Record 38 of Set 14 | san jose
# Processing Record 39 of Set 14 | verkhnevilyuysk
# Processing Record 40 of Set 14 | umm lajj
# Processing Record 41 of Set 14 | rangapara
# Processing Record 42 of Set 14 | torbeyevo
# Processing Record 43 of Set 14 | lubango
# Processing Record 44 of Set 14 | ucluelet
# Processing Record 45 of Set 14 | garowe
# Processing Record 46 of Set 14 | utiroa
# City not found. Skipping...
# Processing Record 47 of Set 14 | abha
# Processing Record 48 of Set 14 | porec
# Processing Record 49 of Set 14 | pitimbu
# Processing Record 50 of Set 14 | fairbanks
# Processing Record 1 of Set 15 | malwan
# City not found. Skipping...
# Processing Record 2 of Set 15 | pyay
# Processing Record 3 of Set 15 | kamenskoye
# City not found. Skipping...
# Processing Record 4 of Set 15 | merauke
# Processing Record 5 of Set 15 | rio grande
# Processing Record 6 of Set 15 | najran
# Processing Record 7 of Set 15 | belorechensk
# Processing Record 8 of Set 15 | indramayu
# Processing Record 9 of Set 15 | boyolangu
# Processing Record 10 of Set 15 | zhanakorgan
# Processing Record 11 of Set 15 | saint-pierre
# Processing Record 12 of Set 15 | manggar
# Processing Record 13 of Set 15 | paka
# Processing Record 14 of Set 15 | harper
# Processing Record 15 of Set 15 | carballo
# Processing Record 16 of Set 15 | talaya
# Processing Record 17 of Set 15 | derzhavinsk
# Processing Record 18 of Set 15 | kudahuvadhoo
# Processing Record 19 of Set 15 | fuling
# Processing Record 20 of Set 15 | roald
# Processing Record 21 of Set 15 | hofn
# Processing Record 22 of Set 15 | lamar
# Processing Record 23 of Set 15 | dawei
# Processing Record 24 of Set 15 | port-cartier
# Processing Record 25 of Set 15 | lerik
# Processing Record 26 of Set 15 | pescara
# Processing Record 27 of Set 15 | college
# Processing Record 28 of Set 15 | atar
# Processing Record 29 of Set 15 | bonavista
# Processing Record 30 of Set 15 | hauterive
# Processing Record 31 of Set 15 | akyab
# Processing Record 32 of Set 15 | eydhafushi
# Processing Record 33 of Set 15 | berekum
# Processing Record 34 of Set 15 | weiser
# Processing Record 35 of Set 15 | akdepe
# Processing Record 36 of Set 15 | pandan
# Processing Record 37 of Set 15 | montepuez
# Processing Record 38 of Set 15 | teguise
# Processing Record 39 of Set 15 | toliary
# City not found. Skipping...
# Processing Record 40 of Set 15 | bac lieu
# Processing Record 41 of Set 15 | qui nhon
# Processing Record 42 of Set 15 | fairmont
# Processing Record 43 of Set 15 | nusaybin
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Rikitea -23.1203 -134.9692     78.76        74           6
# 1        Douentza  14.9951   -2.9517    101.17        19          11
# 2  Port Elizabeth -33.9180   25.5701     69.31        79          74
# 3      Bredasdorp -34.5322   20.0403     70.63        58          60
# 4           Kapaa  22.0752 -159.3190     66.18        66          99
# 5            Hilo  19.7297 -155.0900     69.62        87          22
# 6          Albany  42.6001  -73.9662     45.45        70         100
# 7       Carnarvon -24.8667  113.6333     77.45        70          60
# 8          Rivers  50.0308 -100.2403      2.77        93          64
# 9       Nishihara  26.1842  127.7558     67.28        88          75
#
#    Wind Speed Country                 Date Current Description
# 0       14.25      PF  2022-03-26 14:02:51           clear sky
# 1        8.01      ML  2022-03-26 14:02:52          few clouds
# 2        3.00      ZA  2022-03-26 14:02:53       broken clouds
# 3       18.21      ZA  2022-03-26 14:02:53       broken clouds
# 4       13.09      US  2022-03-26 14:02:19     overcast clouds
# 5        1.99      US  2022-03-26 13:57:05          few clouds
# 6        3.69      US  2022-03-26 13:59:50     overcast clouds
# 7       12.68      AU  2022-03-26 14:02:54       broken clouds
# 8        5.28      CA  2022-03-26 14:02:55       broken clouds
# 9       10.36      JP  2022-03-26 14:02:55          light rain

# %%
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]

# %%
# Create the output file (CSV).
output_data_file = "weather_database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
